# %% [markdown]
# <a href="https://colab.research.google.com/github/ASiso-m/CursoLeo/blob/main/ASprueba2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Obtener datos de Serie de Actividad de Chile -original y desestacionalizada desde 2004 hasta la fecha- para el seguimiento de actividad regional
# Se siguió la propuesta del Banco Central de Chile

import requests

# %%
pip install bcchapi

# %%
import bcchapi

# Incluye credenciales explícitamente
siete = bcchapi.Siete("sisoamelia@gmail.com", "EMAEchile1")
# Se puede hacer llamando a un archivo
# siete = bcchapi.Siete(file="credenciales.txt")
# El parámetro file debe llamar a un documento que contenga en su primera línea el usuario y en la segunda la contraseña.
# ver ejercicio alphacast por la clave

# %%
# Create a file named credenciales.txt and write the credentials. Se usa esta o la anterior, no las dos.
# Si se usa este, sacar las marcas ##

## import bcchapi

## with open("credenciales.txt", "w") as f:
    ## f.write("sisoamelia@gmail.com\n")  # Replace 'your_username' with your actual username
    ## f.write("EMAEchile1\n")  # Replace 'your_password' with your actual password

## print("credenciales.txt created successfully.")

## siete = bcchapi.Siete (file="credenciales.txt")
# Out:
# credenciales.txt created successfully.

# %%
import numpy as np
siete.cuadro(
  series=["F032.IMC.IND.Z.Z.EP18.Z.Z.0.M", "F032.IMC.IND.Z.Z.EP18.Z.Z.1.M"],
  nombres = ["imacec", "imacecse"],
  desde="2004-01-01",
  hasta="2025-05-01",
  # variacion=12,
  frecuencia="M",
  observado={"imacec":np.mean, "imacecse":np.mean}
  # observado se puede usar con np.mean o "last", aparentemente en este caso no cambia nada
  )
# Out:
# /usr/local/lib/python3.11/dist-packages/bcchapi/siete.py:132: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampled = df.resample(frequency, **resample_kw)
# /usr/local/lib/python3.11/dist-packages/bcchapi/siete.py:133: FutureWarning: The provided callable <function mean at 0x7c6e304063e0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df = resampled.aggregate(observed, **aggregate_kw)
#                 imacec    imacecse
# 2004-01-31   56.955084   57.509227
# 2004-02-29   54.856650   57.857238
# 2004-03-31   61.862996   58.485585
# 2004-04-30   60.637087   58.832338
# 2004-05-31   60.085064   59.082033
# ...                ...         ...
# 2025-01-31  110.994504  112.940974
# 2025-02-28  104.247666  111.985835
# 2025-03-31  119.314147  112.805054
# 2025-04-30  113.920917  113.550831
# ...
